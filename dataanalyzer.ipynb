# %% [markdown]
# <a href="https://colab.research.google.com/github/erameh6/Data-Analyzer/blob/main/dataanalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install reportlab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 82.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
import tkinter as tk
from tkinter import filedialog
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

class DataAnalyzer:
    def __init__(self):
        self.data = None

    def load_data(self, file_path, file_type):
        if file_type == 'csv':
            self.data = pd.read_csv(file_path)
        elif file_type == 'excel':
            self.data = pd.read_excel(file_path)
        elif file_type == 'json':
            self.data = pd.read_json(file_path)
        else:
            print("Invalid file type. Please provide a valid file type.")

    def clean_data(self):
        # Handle missing values
        self.data = self.data.dropna()

        # Remove outliers
        # Add code to remove outliers

        # Normalize data
        # Add code to normalize data

        # Perform other preprocessing tasks
        # Add code for other preprocessing tasks

    def perform_eda(self):
        # Perform statistical analysis
        summary_stats = self.data.describe()

        # Identify patterns and generate insights
        # Add code for EDA analysis

        # Visualize data
        sns.pairplot(self.data)
        plt.show()

    def apply_machine_learning(self):
        # Implement machine learning models
        if 'feature1' in self.data.columns and 'feature2' in self.data.columns and 'target' in self.data.columns:
            X = self.data[['feature1', 'feature2']]
            y = self.data['target']
            model = LinearRegression()
            model.fit(X, y)

            # Example: K-Means Clustering
            kmeans = KMeans(n_clusters=3)
            kmeans.fit(X)
            labels = kmeans.labels_

            # Extract valuable information from data
            # Add code to extract information from models
        else:
            print("One or more required columns not found in the dataset.")

    def visualize_data(self):
        # Create visualizations using Matplotlib, Seaborn, Plotly, etc.
        # Example: Bar chart
        if 'x' in self.data.columns and 'y' in self.data.columns:
            plt.bar(self.data['x'], self.data['y'])
            plt.xlabel('X-axis')
            plt.ylabel('Y-axis')
            plt.title('Data Visualization')
            plt.show()
        else:
            print("One or more required columns not found in the dataset.")


    def generate_report(self):
        # Generate automated reports summarizing the analysis
        # Example: Generate PDF report
        pdf = canvas.Canvas('report.pdf', pagesize=letter)
        pdf.drawString(100, 750, "Data Analysis Report")
        pdf.save()


    def run(self, file_path):
        file_type = file_path.split('.')[-1]

        self.load_data(file_path, file_type)
        self.clean_data()
        self.perform_eda()
        self.apply_machine_learning()
        self.visualize_data()
        self.generate_report()

# Example usage
analyzer = DataAnalyzer()
file_path = '/content/dataset.csv'  # Update with the actual path to your dataset file
analyzer.run(file_path)
# Out:
# One or more required columns not found in the dataset.
# One or more required columns not found in the dataset.
